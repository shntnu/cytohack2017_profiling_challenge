# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
data = {'ABCA12': ['mild inhibition of secretion'],
 'ABI1': ['doughnut nuclei',
  'high local density',
  'high Neighbor Fraction',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'low YAP/TAZ ratio (rabbit Novus)'],
 'ACAT1': ['antibody localized in mitochondria'],
 'ACAT2': ['strong inhibition of secretion'],
 'ACP1': ['GFP localization: mitochondria'],
 'ACTB': ['cell shape bipolar or elongated',
  'cell shape geometric',
  'decreased cell number',
  'increased cell size',
  'increased level of actin',
  'increased number of actin puncta or dots',
  'increased number of actin stress fibres',
  'increased number of cortical actin stress fibres',
  'increased number of transverse actin stress fibres',
  'increased number of zigzag actin stress fibres',
  'increased peripheral actin',
  'increased width of lamellae',
  'microtubule processes',
  'motile lamellae'],
 'ACTRT1': ['cell shape bipolar or elongated',
  'cell shape processes or spiky or stretchy',
  'decreased cell number',
  'increased width of lamellae',
  'large (automatic)',
  'microtubule processes',
  'misshapen DNA',
  'nuclear actin ring'],
 'ADH5': ['GFP localization: cytosol'],
 'AGPAT2': ['strong inhibition of secretion'],
 'AGPS': ['mild inhibition of secretion'],
 'AHCTF1': ['other phenotype'],
 'AKIRIN2': ['protein localized in PML bodies'],
 'AKT1S1': ['de-enriched for huge',
  'de-enriched for multi-nucleate',
  'de-enriched for slightly large',
  'de-enriched for small asymmetric cells',
  'enriched for extremely elongated',
  'enriched for slightly elongated',
  'normal cell density'],
 'ALDH3A1': ['mild inhibition of secretion'],
 'ALDH6A1': ['mild inhibition of secretion'],
 'ALG13': ['GFP localization: ER'],
 'ALX3': ['migration (speed) (automatic)'],
 'AMBP': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'ANKS3': ['bright nuclei'],
 'AOAH': ['dynamic changes (automatic)'],
 'ARHGAP29': ['Fan',
  'High nuclear YAP/TAZ',
  'Large, spread',
  'Low nuclear YAP/TAZ',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'Round, small'],
 'ARHGEF3': ['high YAP/TAZ ratio (rabbit Novus)',
  'large cells',
  'Large, spread',
  'low local density',
  'Low nuclear YAP/TAZ',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'Spindly',
  'Triangular'],
 'ARID1B': ['mild inhibition of secretion'],
 'ARL13B': ['binuclear (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'nuclei stay close together (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'ARL6IP4': ['protein localized in nuclear speckles'],
 'ARPC5L': ['cell shape bipolar or elongated',
  'cell shape geometric',
  'cell shape round or non-adherent',
  'cell shape variable',
  'decreased cell number',
  'disorganised peripheral actin',
  'increased actin over nucleus',
  'increased cell size',
  'increased number of actin stress fibres',
  'increased number of transverse actin stress fibres',
  'increased width of lamellae',
  'microtubule nuclear bracket',
  'microtubule nuclear ring',
  'motile lamellae'],
 'ASAP2': ['strong inhibition of secretion'],
 'ASRGL1': ['migration (distance) (automatic)',
  'migration (speed) (automatic)'],
 'ATE1': ['GFP localization: below threshold',
  'GFP localization: cytosol',
  'GFP localization: technical problem'],
 'ATF1': ['GFP localization: below threshold', 'GFP localization: cytosol'],
 'ATG10': ['dynamic changes (automatic)',
  'GFP localization: below threshold',
  'GFP localization: cytosol',
  'GFP localization: technical problem'],
 'ATP2A1': ['mild inhibition of secretion'],
 'B4GALT3': ['increased proliferation (automatic)'],
 'B4GALT5': ['strong inhibition of secretion'],
 'BET1': ['cell shape variable',
  'decreased cell number',
  'decreased level of actin',
  'loss of cell monolayer'],
 'BPNT1': ['cell death (automatic)'],
 'BRDT': ['high Neighbor Fraction',
  'high nucleus/cell area',
  'high YAP/TAZ ratio (rabbit Novus)',
  'large nuclei',
  'low nuclear roundness',
  'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'BTF3L4': ['migration (speed) (automatic)'],
 'C12orf54': ['mild inhibition of secretion'],
 'C17orf74': ['mild inhibition of secretion'],
 'C19orf35': ['binuclear (automatic)',
  'migration (speed) (automatic)',
  'nuclei stay close together (manual)',
  'strong inhibition of secretion'],
 'C19orf54': ['cell death (automatic)',
  'grape (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'nuclei stay close together (manual)',
  'strange nuclear shape (manual)'],
 'C1QL4': ['actin fiber cells'],
 'C1orf64': ['mild inhibition of secretion'],
 'CAMKK2': ['doughnut nuclei',
  'high Neighbor Fraction',
  'large nuclei',
  'low nuclear roundness',
  'low total YAP/TAZ'],
 'CAPG': ['cell death (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'polylobed (automatic)'],
 'CARD10': ['doughnut nuclei',
  'elongated cells',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'high YAP/TAZ ratio (rabbit Novus)',
  'large cells',
  'large nuclei',
  'low nuclear roundness'],
 'CCDC93': ['other phenotype', 'strong inhibition of secretion'],
 'CCL3L3': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'CCNT1': ['cell death (automatic)',
  'dynamic changes (automatic)',
  'mild inhibition of secretion'],
 'CCT7': ['GFP localization: below threshold', 'GFP localization: cytosol'],
 'CD7': ['high Neighbor Fraction',
  'large cells',
  'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'CDK8': ['defective cell-cell aggregation'],
 'CDKN2B': ['high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'low nuclear roundness'],
 'CEP135': ['metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'prometaphase delay/arrest (manual)',
  'strange nuclear shape (manual)'],
 'CFL1': ['bright nuclei',
  'cell shape geometric',
  'cell shape round or non-adherent',
  'cell shape variable',
  'decreased cell number',
  'increased cell size',
  'increased cytoplasmic actin',
  'increased level of actin',
  'increased number of actin puncta or dots',
  'increased number of actin stress fibres',
  'increased number of cortical actin stress fibres',
  'increased number of filopodia',
  'increased number of multinucleate cells',
  'increased number of transverse actin stress fibres',
  'increased number of zigzag actin stress fibres',
  'increased peripheral actin',
  'increased width of lamellae',
  'microtubule nuclear bracket',
  'misshapen DNA',
  'nuclear actin ring',
  'SM phenotype (round cells and many in metaphase)'],
 'CHD8': ['mild inhibition of secretion'],
 'CHUK': ['high local density',
  'high nucleus/cell area',
  'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'CKM': ['low YAP/TAZ ratio (mouse Santa Cruz)'],
 'CLCA2': ['strong inhibition of secretion'],
 'CLDN14': ['mild inhibition of secretion'],
 'CLK3': ['doughnut nuclei',
  'high nucleus/cell area',
  'low Neighbor Fraction',
  'low total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'low YAP/TAZ ratio (rabbit Novus)',
  'migration (distance) (automatic)',
  'migration (speed) (automatic)',
  'small cells',
  'small nuclei',
  'strong inhibition of secretion'],
 'CLSPN': ['BL phenotype (large cells and bright nuclei)'],
 'CNDP2': ['mild inhibition of secretion'],
 'CNOT4': ['other phenotype'],
 'CNTN6': ['polylobed (automatic)'],
 'COCH': ['metaphase alignment problems/including no metaphase (manual)',
  'strange nuclear shape (manual)'],
 'COG3': ['GFP localization: punctate'],
 'COL19A1': ['cell death (automatic)'],
 'COQ4': ['GFP localization: mitochondria'],
 'COQ5': ['abnormal microtubule cytoskeleton morphology during mitotic interphase'],
 'CPA2': ['actin cytoskeleton phenotype',
  'aggregated cells in population',
  'apoptopic nucleus phenotype',
  'apoptotic cell shape phenotype',
  'bilobed nucleus phenotype',
  'binuclear cell phenotype',
  'bright nuclear body phenotype',
  'cell adhesion phenotype',
  'cell DNA phenotype',
  'cell-matrix adhesion phenotype',
  'cell morphology phenotype',
  'increased cell size phenotype',
  'increased thickness of dendritic branches phenotype',
  'metabolic process phenotype',
  'misshapen DNA',
  'M phase mitotic phenotype',
  'nuclear morphology phenotype',
  'polyploid cell phenotype'],
 'CSAD': ['other phenotype', 'strong inhibition of secretion'],
 'CSF3R': ['mild inhibition of secretion'],
 'CSN1S1': ['mild inhibition of secretion'],
 'CSNK2A2': ['high nucleus/cell area',
  'low Neighbor Fraction',
  'low total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'small cells'],
 'CTRL': ['cell death (automatic)',
  'dynamic changes (automatic)',
  'grape (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'mitotic delay/arrest (automatic)',
  'strange nuclear shape (manual)'],
 'CXCL1': ['metaphase cells'],
 'CXorf36': ['migration (distance) (automatic)',
  'migration (speed) (automatic)',
  'mild inhibition of secretion'],
 'CYP46A1': ['binuclear (automatic)', 'dynamic changes (automatic)'],
 'DCBLD2': ['mild inhibition of secretion'],
 'DCDC5': ['mild inhibition of secretion'],
 'DDX3X': ['mild inhibition of secretion'],
 'DFFA': ['migration (speed) (automatic)', 'other phenotype'],
 'DHRS9': ['other phenotype'],
 'DIO3': ['other phenotype'],
 'DISC1': ['cell death (automatic)'],
 'DLAT': ['mild inhibition of secretion'],
 'DLD': ['mitotic delay/arrest (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'DLG4': ['high YAP/TAZ ratio (mouse Santa Cruz)',
  'high YAP/TAZ ratio (rabbit Novus)',
  'low total YAP/TAZ',
  'other phenotype'],
 'DNAH12': ['strong inhibition of secretion'],
 'DOCK1': ['high Neighbor Fraction',
  'high total YAP/TAZ',
  'High total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'large cells',
  'Low nuclear YAP/TAZ',
  'Spindly'],
 'DOCK9': ['High total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'Large, spread',
  'Low nuclear YAP/TAZ',
  'low total YAP/TAZ',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'nuclei stay close together (manual)',
  'Round, small',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'small cells',
  'Spindly',
  'strange nuclear shape (manual)',
  'Triangular'],
 'DPY19L2': ['mild inhibition of secretion'],
 'DUSP8': ['enhanced secretion',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'large nuclei',
  'low nuclear roundness',
  'metaphase alignment problems/including no metaphase (manual)',
  'nuclei stay close together (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'DYNC2LI1': ['mild inhibition of secretion'],
 'DYNLL1': ['strong inhibition of secretion'],
 'EIF3E': ['elongated cells'],
 'ELF3': ['binuclear (automatic)', 'elongated cells'],
 'ELK1': ['cell death (automatic)',
  'de-enriched for extremely elongated',
  'de-enriched for extremely triangular',
  'de-enriched for slightly elongated',
  'de-enriched for slightly large',
  'enriched for multi-nucleate',
  'enriched for telophase/late telophase',
  'low cell density',
  'mitotic delay/arrest (automatic)',
  'nuclei stay close together (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'ENOX2': ['dynamic changes (automatic)',
  'high actin ratio cells',
  'polylobed (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)',
  'strong inhibition of secretion'],
 'EPHA2': ['doughnut nuclei',
  'low nuclear roundness',
  'low total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'mild inhibition of secretion'],
 'ERCC4': ['binuclear (automatic)'],
 'ESYT2': ['mild inhibition of secretion'],
 'ETF1': ['abnormal microtubule cytoskeleton morphology during mitotic interphase',
  'viable elongated vegetative cell',
  'viable vegetative cell with abnormal cell shape'],
 'FAM199X': ['antibody localized in cytoplasm',
  'antibody localized in Golgi apparatus',
  'antibody localized in nucleus',
  'strong inhibition of secretion'],
 'FAM98A': ['strong inhibition of secretion'],
 'FAU': ['other phenotype'],
 'FBP2': ['defective cell-cell aggregation'],
 'FBXO21': ['other phenotype'],
 'FBXO27': ['other phenotype'],
 'FBXO42': ['mild inhibition of secretion'],
 'FCGRT': ['strong inhibition of secretion'],
 'FGD4': ['Fan',
  'high Neighbor Fraction',
  'high total YAP/TAZ',
  'large cells',
  'large nuclei',
  'Large, spread',
  'low nuclear roundness',
  'Low nuclear YAP/TAZ',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'Round, small',
  'Spindly',
  'Triangular'],
 'FGF2': ['migration (speed) (automatic)', 'mild inhibition of secretion'],
 'FGF7': ['mild inhibition of secretion'],
 'FIZ1': ['mild inhibition of secretion'],
 'FKBPL': ['mild inhibition of secretion'],
 'FMN1': ['big cells',
  'GFP localization: below threshold',
  'GFP localization: cytosol'],
 'FN3KRP': ['high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'low total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'small cells'],
 'FPR1': ['GFP localization: cytosol'],
 'GABARAPL2': ['strong inhibition of secretion'],
 'GABRG1': ['mild inhibition of secretion'],
 'GDF7': ['mild inhibition of secretion'],
 'GID8': ['GFP localization: cytosol', 'GFP localization: nucleus'],
 'GJD3': ['mild inhibition of secretion'],
 'GLRX2': ['strong inhibition of secretion'],
 'GMEB1': ['other phenotype'],
 'GON7': ['altered kinetochore foci'],
 'GPAT2': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'GPR183': ['mild inhibition of secretion'],
 'GPR19': ['binuclear (automatic)',
  'nuclei stay close together (manual)',
  'polylobed (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'GRK1': ['high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'large cells',
  'low total YAP/TAZ'],
 'GSTA3': ['mild inhibition of secretion'],
 'GTF2IRD1': ['large nuclei', 'strong inhibition of secretion'],
 'GTPBP4': ['mild inhibition of secretion'],
 'GUCY2F': ['high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'low total YAP/TAZ'],
 'H6PD': ['mild inhibition of secretion'],
 'HAP1': ['cell death (automatic)'],
 'HAPLN2': ['mild inhibition of secretion', 'other phenotype'],
 'HAUS3': ['metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'polylobed (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'HCFC2': ['strong inhibition of secretion'],
 'HEXIM2': ['cell death (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)'],
 'HFM1': ['GFP localization: below threshold', 'GFP localization: cytosol'],
 'HIGD1A': ['mild inhibition of secretion'],
 'HIST1H2BO': ['other phenotype'],
 'HIST1H4A': ['large (automatic)'],
 'HK1': ['antibody localized in mitochondria',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'polylobed (automatic)'],
 'HLTF': ['strong inhibition of secretion'],
 'HSPA4L': ['other phenotype'],
 'HTR5A': ['binuclear (automatic)',
  'dynamic changes (automatic)',
  'polylobed (automatic)'],
 'ICK': ['dynamic changes (automatic)',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'high YAP/TAZ ratio (rabbit Novus)',
  'mild inhibition of secretion'],
 'ID3': ['cell death (automatic)'],
 'IER3IP1': ['actin fiber cells'],
 'IL21': ['strong inhibition of secretion'],
 'INCENP': ['defective cell-cell aggregation'],
 'INPP5D': ['mild inhibition of secretion'],
 'INPP5F': ['mild inhibition of secretion'],
 'ISLR': ['metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)'],
 'ITFG2': ['dynamic changes (automatic)'],
 'ITGB1BP1': ['doughnut nuclei',
  'high YAP/TAZ ratio (rabbit Novus)',
  'large cells',
  'low local density',
  'low nucleus/cell area'],
 'ITGB2': ['mild inhibition of secretion'],
 'JARID2': ['cell death (automatic)', 'large (automatic)'],
 'KCNK12': ['cell death (automatic)', 'dynamic changes (automatic)'],
 'KCTD3': ['mild inhibition of secretion'],
 'KHK': ['high Neighbor Fraction',
  'high total YAP/TAZ',
  'large cells',
  'low nucleus/cell area',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'low YAP/TAZ ratio (rabbit Novus)',
  'strong inhibition of secretion'],
 'KIAA1147': ['mild inhibition of secretion'],
 'KIF1C': ['low eccentricity cells', 'strong inhibition of secretion'],
 'KIF25': ['mild inhibition of secretion'],
 'KIR3DL3': ['strong inhibition of secretion'],
 'KRI1': ['GFP localization: cytosol',
  'GFP localization: nucleus',
  'GFP localization: punctate',
  'strong inhibition of secretion'],
 'KRT6C': ['migration (distance) (automatic)',
  'migration (speed) (automatic)',
  'mild inhibition of secretion'],
 'LBR': ['lamellipodia cells'],
 'LCE2D': ['mild inhibition of secretion'],
 'LCE5A': ['metaphase alignment problems/including no metaphase (manual)',
  'mitotic delay/arrest (automatic)',
  'strange nuclear shape (manual)'],
 'LCK': ['cell death (automatic)',
  'high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'high total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'low YAP/TAZ ratio (rabbit Novus)',
  'nuclei stay close together (manual)',
  'polylobed (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'small cells',
  'strange nuclear shape (manual)'],
 'LCTL': ['mild inhibition of secretion'],
 'LILRB1': ['BL phenotype (large cells and bright nuclei)'],
 'LRG1': ['GFP localization: bud neck', 'GFP localization: cytosol'],
 'LRRC46': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'LRRC66': ['mild inhibition of secretion'],
 'LRRTM2': ['large (automatic)'],
 'LSM14A': ['cell death (automatic)',
  'grape (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'mitotic delay/arrest (automatic)',
  'polylobed (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)',
  'strong inhibition of secretion'],
 'LSP1': ['GFP localization: below threshold', 'GFP localization: cytosol'],
 'LUC7L3': ['strong inhibition of secretion'],
 'LYZ': ['mild inhibition of secretion'],
 'MAGEB17': ['mild inhibition of secretion'],
 'MAMDC4': ['binuclear (automatic)'],
 'MAP2K3': ['de-enriched for extremely triangular',
  'de-enriched for multi-nucleate',
  'de-enriched for slightly elongated',
  'enriched for huge',
  'enriched for slightly large',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'large cells',
  'large nuclei',
  'low cell density'],
 'MAP3K7': ['de-enriched for extremely elongated',
  'de-enriched for extremely triangular',
  'enriched for multi-nucleate',
  'enriched for slightly large',
  'enriched for small asymmetric cells',
  'enriched for telophase/late telophase',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'low total YAP/TAZ',
  'normal cell density'],
 'MAST3': ['doughnut nuclei',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'large cells',
  'low nuclear roundness',
  'low nucleus/cell area',
  'strong inhibition of secretion'],
 'MASTL': ['binuclear (automatic)',
  'high Neighbor Fraction',
  'low local density',
  'low total YAP/TAZ'],
 'MBOAT1': ['mild inhibition of secretion'],
 'MCM5': ['GFP localization: below threshold', 'GFP localization: cytosol'],
 'MCM6': ['GFP localization: nucleus', 'large (automatic)'],
 'MDH1': ['GFP localization: mitochondria', 'mild inhibition of secretion'],
 'MDN1': ['strong inhibition of secretion'],
 'MECP2': ['mild inhibition of secretion'],
 'MED12': ['binuclear (automatic)'],
 'MED20': ['abnormal microtubule cytoskeleton morphology during mitotic interphase',
  'microtubule bundles present in greater numbers',
  'S-shaped cell',
  'viable elongated vegetative cell',
  'viable vegetative cell with abnormal cell shape'],
 'MED4': ['cell shape variable',
  'decreased cell number',
  'decreased level of actin',
  'defective cell-cell aggregation',
  'GFP localization: nucleus',
  'loss of cell monolayer',
  'mild inhibition of secretion'],
 'MELK': ['doughnut nuclei',
  'high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'large nuclei',
  'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'MEPCE': ['mild inhibition of secretion'],
 'MERTK': ['high local density',
  'high Neighbor Fraction',
  'large cells',
  'large nuclei',
  'low total YAP/TAZ'],
 'MET': ['doughnut nuclei',
  'high local density',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'large cells'],
 'METRNL': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'METTL3': ['strong inhibition of secretion'],
 'MRM1': ['GFP localization: mitochondria'],
 'MRPL10': ['GFP localization: mitochondria'],
 'MRPL15': ['GFP localization: mitochondria'],
 'MRPL4': ['altered kinetochore foci',
  'cell death (automatic)',
  'GFP localization: mitochondria'],
 'MRPL53': ['decreased cell size',
  'decreased level of actin',
  'increased number of multinucleate cells'],
 'MRPS5': ['GFP localization: mitochondria', 'strong inhibition of secretion'],
 'MT-CO2': ['cell death (automatic)', 'mild inhibition of secretion'],
 'MUTYH': ['dynamic changes (automatic)',
  'other phenotype',
  'strong inhibition of secretion'],
 'MXI1': ['mild inhibition of secretion'],
 'MYD88': ['binuclear (automatic)'],
 'MYO1G': ['cell shape bipolar or elongated',
  'cell shape processes or spiky or stretchy',
  'decreased cell number',
  'disorganised peripheral actin',
  'increased mitotic index',
  'increased number of actin puncta or dots',
  'increased number of actin stress fibres',
  'increased number of filopodia',
  'increased peripheral actin',
  'increased width of lamellae',
  'loss of cell monolayer',
  'microtubule processes',
  'microtubules disorganised'],
 'MYSM1': ['lamellipodia cells'],
 'NAV3': ['strong inhibition of secretion'],
 'NDUFV2': ['other phenotype'],
 'NFIA': ['mild inhibition of secretion', 'other phenotype'],
 'NFS1': ['GFP localization: mitochondria'],
 'NIP7': ['altered kinetochore foci',
  'GFP localization: below threshold',
  'GFP localization: cytosol'],
 'NKX6-3': ['mild inhibition of secretion'],
 'NOL7': ['mild inhibition of secretion', 'protein localized in nucleolus'],
 'NOLC1': ['cell death (automatic)',
  'protein localized in nucleolus',
  'strong inhibition of secretion'],
 'NPC1L1': ['strong inhibition of secretion'],
 'NR2F2': ['large (automatic)'],
 'NSFL1C': ['cell death (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)'],
 'NSL1': ['GFP localization: punctate'],
 'NSMCE1': ['other phenotype'],
 'NT5C1A': ['cell death (automatic)'],
 'NT5C2': ['other phenotype', 'strong inhibition of secretion'],
 'NUFIP1': ['dynamic changes (automatic)'],
 'NUP188': ['GFP localization: below threshold',
  'GFP localization: cytosol',
  'mild inhibition of secretion',
  'strong inhibition of secretion'],
 'NUP214': ['large (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'nuclei stay close together (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'ODF2': ['actin fiber cells'],
 'OR10V1': ['mild inhibition of secretion', 'other phenotype'],
 'OR4N2': ['high actin ratio cells'],
 'OR51M1': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'OR52L1': ['mild inhibition of secretion'],
 'OR56A3': ['mild inhibition of secretion'],
 'OR5B2': ['strong inhibition of secretion'],
 'OR5D14': ['migration (speed) (automatic)', 'mild inhibition of secretion'],
 'OR5M8': ['mild inhibition of secretion'],
 'OR7A10': ['strong inhibition of secretion'],
 'OR9A4': ['migration (speed) (automatic)', 'polylobed (automatic)'],
 'ORC2': ['altered kinetochore foci', 'GFP localization: nucleus'],
 'OSBP2': ['increased proliferation (automatic)',
  'mild inhibition of secretion'],
 'OXGR1': ['polylobed (automatic)'],
 'PACS1': ['strong inhibition of secretion'],
 'PAM16': ['GFP localization: mitochondria'],
 'PAPSS1': ['high local density',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'low total YAP/TAZ',
  'metaphase alignment problems/including no metaphase (manual)',
  'mitotic delay/arrest (automatic)',
  'strange nuclear shape (manual)'],
 'PBX3': ['large (automatic)'],
 'PDCD5': ['metaphase cells'],
 'PEX11G': ['other phenotype'],
 'PFKL': ['high Neighbor Fraction',
  'high total YAP/TAZ',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'high YAP/TAZ ratio (rabbit Novus)',
  'large cells',
  'large nuclei',
  'low local density'],
 'PGLYRP1': ['strong inhibition of secretion'],
 'PGM5': ['strong inhibition of secretion'],
 'PHF2': ['strong inhibition of secretion'],
 'PICALM': ['strong inhibition of secretion'],
 'PIK3C3': ['other phenotype'],
 'PIPOX': ['abnormal chromosome segregation phenotype',
  'actin filament phenotype',
  'aggregated cells in population',
  'cell adhesion phenotype',
  'cell component size phenotype',
  'cell component structure phenotype',
  'cell projection phenotype',
  'cellular component phenotype',
  'decreased axon thickness phenotype',
  'increased rate of protein secretion',
  'more cells in M phase'],
 'PITPNM2': ['antibody localized in vesicles'],
 'PJA1': ['protein localized in PML bodies', 'shorter prophase'],
 'PKIB': ['doughnut nuclei',
  'high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'mild inhibition of secretion',
  'other phenotype',
  'small cells'],
 'PLEKHG6': ['Large, spread',
  'low total YAP/TAZ',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'Spindly',
  'Triangular'],
 'PLEKHM2': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'PLXNC1': ['polylobed (automatic)'],
 'PNMA5': ['strong inhibition of secretion'],
 'POP1': ['GFP localization: below threshold',
  'GFP localization: cytosol',
  'other phenotype'],
 'PPP4R1': ['strong inhibition of secretion'],
 'PRPSAP1': ['cell death (automatic)',
  'low local density',
  'low nuclear roundness',
  'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'PRRC1': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'PRSS48': ['mild inhibition of secretion'],
 'PSKH1': ['low YAP/TAZ ratio (mouse Santa Cruz)',
  'mild inhibition of secretion'],
 'PSMA2': ['dynamic changes (automatic)', 'increased DNA damage'],
 'PSMB1': ['increased DNA damage', 'strong inhibition of secretion'],
 'PSMB2': ['cell death (automatic)', 'increased DNA damage'],
 'PTCHD1': ['mild inhibition of secretion'],
 'PTCRA': ['cell death (automatic)'],
 'PTDSS2': ['elongated cells with protrusions',
  'strong inhibition of secretion'],
 'PTK2B': ['large cells', 'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'RAB10': ['migration (distance) (automatic)'],
 'RAB5C': ['migration (distance) (automatic)',
  'migration (speed) (automatic)'],
 'RAPGEF1': ['dynamic changes (automatic)', 'mild inhibition of secretion'],
 'RAPGEF3': ['doughnut nuclei',
  'high nucleus/cell area',
  'high YAP/TAZ ratio (rabbit Novus)',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'small cells',
  'small nuclei'],
 'RBM15B': ['strong inhibition of secretion'],
 'RCC1': ['mild inhibition of secretion',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'RGL1': ['mild inhibition of secretion'],
 'RGP1': ['GFP localization: punctate'],
 'RHOBTB3': ['low local density',
  'low total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'low YAP/TAZ ratio (rabbit Novus)'],
 'RHOC': ['cell shape bipolar or elongated',
  'cell shape processes or spiky or stretchy',
  'decreased cell number',
  'disorganised peripheral actin',
  'high local density',
  'high Neighbor Fraction',
  'increased cell size',
  'increased cytoplasmic actin',
  'increased number of actin puncta or dots',
  'increased number of cortical actin stress fibres',
  'increased number of filopodia',
  'increased peripheral actin',
  'increased width of lamellae',
  'large cells',
  'loss of cell monolayer',
  'low local density',
  'Low nuclear YAP/TAZ',
  'low nucleus/cell area',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'low YAP/TAZ ratio (rabbit Novus)',
  'microtubule processes',
  'motile lamellae',
  'Spindly',
  'strong inhibition of secretion',
  'Triangular'],
 'RHOD': ['dynamic changes (automatic)',
  'High total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'Low nuclear YAP/TAZ',
  'mild inhibition of secretion',
  'Round, small',
  'Spindly',
  'Triangular'],
 'RIN3': ['mild inhibition of secretion'],
 'RIPK4': ['grape (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'mitotic delay/arrest (automatic)',
  'polylobed (automatic)',
  'prometaphase delay/arrest (manual)'],
 'RNASE4': ['binuclear (automatic)', 'mild inhibition of secretion'],
 'RNASE9': ['mild inhibition of secretion'],
 'ROS1': ['high local density',
  'high Neighbor Fraction',
  'high nucleus/cell area',
  'increased proliferation (automatic)',
  'low total YAP/TAZ',
  'low YAP/TAZ ratio (mouse Santa Cruz)',
  'small cells',
  'strong inhibition of secretion'],
 'RPL13A': ['cell shape variable',
  'decreased cell number',
  'decreased level of actin',
  'defective cell-cell aggregation',
  'loss of cell monolayer'],
 'RPS11': ['dynamic changes (automatic)'],
 'RPS26': ['cell shape variable',
  'decreased cell number',
  'decreased level of actin',
  'defective cell-cell aggregation',
  'loss of cell monolayer'],
 'RPS6KB1': ['de-enriched for extremely elongated',
  'de-enriched for extremely triangular',
  'de-enriched for slightly elongated',
  'enriched for slightly large',
  'high Neighbor Fraction',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'large cells',
  'low local density',
  'low nucleus/cell area',
  'low total YAP/TAZ',
  'normal cell density'],
 'RSL1D1': ['protein localized in nucleolus'],
 'RXFP2': ['binuclear (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'RYR1': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'S100A11': ['dynamic changes (automatic)', 'mild inhibition of secretion'],
 'SARS2': ['dynamic changes (automatic)', 'mitotic delay/arrest (automatic)'],
 'SART3': ['metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'SCGB1D1': ['cell death (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)',
  'nuclei stay close together (manual)',
  'polylobed (automatic)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'SCN8A': ['mild inhibition of secretion'],
 'SELPLG': ['strong inhibition of secretion'],
 'SFXN2': ['other phenotype'],
 'SH2B3': ['mild inhibition of secretion'],
 'SHB': ['strong inhibition of secretion'],
 'SHQ1': ['GFP localization: nucleus'],
 'SLC12A8': ['strong inhibition of secretion'],
 'SLC19A1': ['high actin ratio cells'],
 'SLC22A12': ['polylobed (automatic)'],
 'SLC25A22': ['mild inhibition of secretion'],
 'SLC25A46': ['strong inhibition of secretion'],
 'SLC25A5': ['dynamic changes (automatic)', 'polylobed (automatic)'],
 'SLC28A3': ['elongated cells'],
 'SLC4A7': ['mild inhibition of secretion'],
 'SLC5A8': ['large (automatic)', 'mild inhibition of secretion'],
 'SLC6A15': ['cell death (automatic)', 'dynamic changes (automatic)'],
 'SMAD1': ['high actin ratio cells'],
 'SMPD4': ['mild inhibition of secretion'],
 'SNTG1': ['mild inhibition of secretion'],
 'SNX14': ['mild inhibition of secretion'],
 'SNX19': ['lamellipodia cells', 'strong inhibition of secretion'],
 'SPINK14': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'SPINK7': ['other phenotype'],
 'SREBF2': ['metaphase alignment problems/including no metaphase (manual)'],
 'STRN': ['binuclear (automatic)',
  'cell death (automatic)',
  'nuclei stay close together (manual)'],
 'SUB1': ['GFP localization: nucleus', 'large (automatic)'],
 'TACC2': ['enhanced secretion'],
 'TAF13': ['defective cell-cell aggregation'],
 'TAF5': ['GFP localization: below threshold', 'GFP localization: cytosol'],
 'TAF7L': ['mild inhibition of secretion',
  'nuclei stay close together (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)',
  'strong inhibition of secretion'],
 'TAF9B': ['mild inhibition of secretion'],
 'TBCC': ['binuclear (automatic)',
  'cell death (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'metaphase delay/arrest (manual)',
  'mitotic delay/arrest (automatic)'],
 'TBKBP1': ['mild inhibition of secretion'],
 'TESK1': ['cell death (automatic)',
  'high total YAP/TAZ',
  'high YAP/TAZ ratio (mouse Santa Cruz)',
  'high YAP/TAZ ratio (rabbit Novus)',
  'large cells',
  'low local density',
  'low nucleus/cell area',
  'mitotic delay/arrest (automatic)',
  'small cells'],
 'TFIP11': ['binuclear (automatic)',
  'other phenotype',
  'protein localized in an uncharacterized nuclear subcompartment'],
 'TIAF1': ['segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)',
  'strange nuclear shape (manual)'],
 'TIMD4': ['large (automatic)'],
 'TIPARP': ['cell death (automatic)',
  'other phenotype',
  'polylobed (automatic)'],
 'TJP1': ['mild inhibition of secretion'],
 'TLL1': ['other phenotype'],
 'TLR5': ['strong inhibition of secretion'],
 'TMA7': ['GFP localization: cytosol', 'GFP localization: nucleus'],
 'TMEM14B': ['cell death (automatic)'],
 'TMEM205': ['enhanced secretion'],
 'TMEM43': ['mild inhibition of secretion'],
 'TMEM61': ['BL phenotype (large cells and bright nuclei)',
  'mild inhibition of secretion',
  'strong inhibition of secretion'],
 'TMPRSS2': ['strong inhibition of secretion'],
 'TNFRSF10C': ['enhanced secretion'],
 'TNNT1': ['cell death (automatic)', 'dynamic changes (automatic)'],
 'TP63': ['strong inhibition of secretion'],
 'TPD52L3': ['cell death (automatic)'],
 'TPK1': ['GFP localization: cytosol',
  'GFP localization: nucleus',
  'low YAP/TAZ ratio (mouse Santa Cruz)'],
 'TPST1': ['dynamic changes (automatic)'],
 'TREML1': ['large (automatic)', 'mild inhibition of secretion'],
 'TRHR': ['enhanced secretion'],
 'TRIB3': ['high Neighbor Fraction',
  'low total YAP/TAZ',
  'migration (speed) (automatic)',
  'mild inhibition of secretion'],
 'TRIM2': ['mild inhibition of secretion'],
 'TSPAN32': ['strong inhibition of secretion'],
 'TST': ['dynamic changes (automatic)'],
 'TTBK2': ['high Neighbor Fraction'],
 'TTC30B': ['dynamic changes (automatic)'],
 'TTC34': ['mild inhibition of secretion'],
 'TTLL1': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'TUFT1': ['cell death (automatic)', 'dynamic changes (automatic)'],
 'TXNIP': ['large (automatic)'],
 'UBA7': ['mild inhibition of secretion'],
 'UBL4B': ['dynamic changes (automatic)'],
 'UMPS': ['dynamic changes (automatic)',
  'grape (automatic)',
  'metaphase alignment problems/including no metaphase (manual)',
  'mitotic delay/arrest (automatic)',
  'strange nuclear shape (manual)'],
 'USP53': ['mild inhibition of secretion', 'strong inhibition of secretion'],
 'VAV2': ['Fan',
  'High nuclear YAP/TAZ',
  'large cells',
  'large nuclei',
  'low nuclear roundness',
  'low total YAP/TAZ',
  'Low total YAP/TAZ in nuclear and ring regions normalised to nuclear area',
  'Triangular'],
 'VPS41': ['altered kinetochore foci',
  'GFP localization: punctate',
  'GFP localization: vacuole membrane',
  'the smt3allR mutant population contains odd shaped cells and the smt3allR mutant population displays an increased number of cells with foci'],
 'WDR5B': ['nuclei stay close together (manual)',
  'segregation problems/chromatin bridges/lagging chromosomes/multiple DNA masses (manual)'],
 'ZBED4': ['strong inhibition of secretion'],
 'ZCCHC13': ['cell death (automatic)'],
 'ZDHHC17': ['cell death (automatic)'],
 'ZDHHC6': ['other phenotype'],
 'ZFAND2B': ['mild inhibition of secretion'],
 'ZFP36L2': ['mild inhibition of secretion'],
 'ZMYM6': ['mild inhibition of secretion'],
 'ZNF165': ['cell death (automatic)', 'polylobed (automatic)'],
 'ZNF358': ['cell death (automatic)',
  'dynamic changes (automatic)',
  'elongated cells',
  'mitotic delay/arrest (automatic)',
  'polylobed (automatic)'],
 'ZNF560': ['mild inhibition of secretion'],
 'ZNF747': ['strong inhibition of secretion'],
 'ZNF770': ['mild inhibition of secretion'],
 'ZNRF3': ['other phenotype']}

# %%
genes = data.keys()
print(len(genes))
# Out:
# 396

# %%
phenotypes = []
for k in genes:
    phenotypes += data[k]
    
phenotypes = list(set(phenotypes))
print(len(phenotypes))
# Out:
# 159

# %%
genes = list(genes)
phenotypes = list(phenotypes)

# %%
matrix = np.zeros( (len(genes), len(phenotypes)) )
gene_index = {}
for i in range(len(genes)):
    gene_index[genes[i]] = i
phenotype_index = {}
for i in range(len(phenotypes)):
    phenotype_index[phenotypes[i]] = i
    
for g in genes:
    for d in data[g]:
        matrix[gene_index[g], phenotype_index[d]] = 1

# %%
grid = sb.clustermap(matrix, figsize=(15,15))
# Out:
# /Users/jcaicedo/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
df = pd.DataFrame(matrix, index=genes, columns=phenotypes)
df.to_csv("cyto_vis.csv")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 396 entries, ABCA12 to ZNRF3
# Columns: 159 entries, increased width of lamellae to small cells
# dtypes: float64(159)
# memory usage: 495.0+ KB
#           increased width of lamellae  cell DNA phenotype  low cell density  \
# ABCA12                            0.0                 0.0               0.0
# ABI1                              0.0                 0.0               0.0
# ACAT1                             0.0                 0.0               0.0
# ACAT2                             0.0                 0.0               0.0
# ACP1                              0.0                 0.0               0.0
# ACTB                              1.0                 0.0               0.0
# ACTRT1                            1.0                 0.0               0.0
# ADH5                              0.0                 0.0               0.0
# AGPAT2                            0.0                 0.0               0.0
# ...

# %%
col_sums = np.sum(matrix, axis=0)
print(col_sums.shape, matrix.shape)
zoom = matrix[:, col_sums > 3]

row_sums = np.sum(zoom, axis=1)
zoom = zoom[row_sums > 3, :]

grid = sb.clustermap(zoom, figsize=(15,15))
# Out:
# (159,) (396, 159)
# /Users/jcaicedo/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
col_sums = np.sum(matrix, axis=1)
row_sums = np.sum(matrix, axis=0)
print(col_sums.shape, row_sums.shape)
# Out:
# (396,) (159,)

# %%
# Out:
#           increased width of lamellae  cell DNA phenotype  low cell density  \
# ABCA12                            0.0                 0.0               0.0
# ABI1                              0.0                 0.0               0.0
# ACAT1                             0.0                 0.0               0.0
# ACAT2                             0.0                 0.0               0.0
# ACP1                              0.0                 0.0               0.0
# ACTB                              1.0                 0.0               0.0
# ACTRT1                            1.0                 0.0               0.0
# ADH5                              0.0                 0.0               0.0
# AGPAT2                            0.0                 0.0               0.0
# AGPS                              0.0                 0.0               0.0
# AHCTF1                            0.0                 0.0               0.0
# ...
